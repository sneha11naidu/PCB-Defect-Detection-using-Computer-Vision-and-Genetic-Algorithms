# %% [markdown]
# # YOLO v9 for Object Detection

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Total 325 (delta 0), reused 0 (delta 0), pack-reused 325
# Receiving objects: 100% (325/325), 2.25 MiB | 2.97 MiB/s, done.
# Resolving deltas: 100% (164/164), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 79.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 69.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 64.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 94.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.8 MB/s eta 0:00:00
# ...

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# Build a YOLOv9c model from scratch
# model = YOLO('yolov9c.yaml')

# Build a YOLOv9c model from pretrained weight
model = YOLO('yolov9c.pt')

# Display model information (optional)
model.info()
# Out:
# ...
# 100%|██████████| 49.4M/49.4M [00:00<00:00, 253MB/s]
# YOLOv9c summary: 618 layers, 25590912 parameters, 0 gradients, 104.0 GFLOPs
# (618, 25590912, 0, 104.02268160000003)

# %%
model.model_name
# Out:
# 'yolov9c.pt'

# %%
# !pwd
# Out:
# /content/yolov9

# %%
# Train the model on the PCB dataset for 10 epochs
results = model.train(data='/content/drive/MyDrive/Machine_Learning_CW/PCB_datasets/PCB_2_D.v1i.yolov9/data.yaml', epochs=20, imgsz=640, batch=16, lr0=0.01, plots=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6c1dc80ae8c9> in <cell line: 2>()
#       1 # Train the model on the PCB dataset for 10 epochs
# ----> 2 results = model.train(data='/content/drive/MyDrive/Machine_Learning_CW/PCB_datasets/PCB_2_D.v1i.yolov9/data.yaml', epochs=20, imgsz=640, batch=16, lr0=0.01, plots=False)
#       3
#
# NameError: name 'model' is not defined

# %%
from sklearn.model_selection import ParameterGrid

# Define your hyperparameter grid as a dictionary
param_grid = {
    'learning_rate': [0.0001, 0.001, 0.01],
    'batch_size': [32, 64, 128],
    # ... include other hyperparameters you want to tune
}


# Use ParameterGrid to create a grid of hyperparameter combinations
parameter_grid = ParameterGrid(param_grid)

# %%
import locale
def getpreferredencoding(do_setlocale = True):
  return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !pwd
# Out:
# /content/yolov9

# %%
model.info()

# (618, 25590912, 0, 104.02268160000003)
# Out:
# YOLOv9c summary: 618 layers, 25533858 parameters, 0 gradients, 103.7 GFLOPs
# (618, 25533858, 0, 103.7044224)

# %%
#from IPython.display import Image

#Image(filename="/content/yolov9/runs/detect/train/results.png", width=1000)

# %%
#Image(filename="/content/yolov9/runs/detect/train/confusion_matrix_normalized.png", width=1000)

# %%
# Image(filename="/content/yolov9/runs/detect/train/val_batch0_pred.jpg", width=1000)

# %%
import locale
def getpreferredencoding(do_setlocale = True):
  return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !zip -r /content/drive/MyDrive/train222.zip /content/yolov9/runs/detect/train222  # Replace paths accordingly
# Out:
#   adding: content/yolov9/runs/detect/train222/ (stored 0%)
#   adding: content/yolov9/runs/detect/train222/PR_curve.png (deflated 18%)
#   adding: content/yolov9/runs/detect/train222/confusion_matrix.png (deflated 38%)
#   adding: content/yolov9/runs/detect/train222/F1_curve.png (deflated 10%)
#   adding: content/yolov9/runs/detect/train222/val_batch0_pred.jpg (deflated 12%)
#   adding: content/yolov9/runs/detect/train222/train_batch720.jpg (deflated 8%)
#   adding: content/yolov9/runs/detect/train222/train_batch721.jpg (deflated 9%)
#   adding: content/yolov9/runs/detect/train222/events.out.tfevents.1711664937.17f64541eb53.688.3 (deflated 91%)
#   adding: content/yolov9/runs/detect/train222/labels_correlogram.jpg (deflated 44%)
#   adding: content/yolov9/runs/detect/train222/results.csv (deflated 85%)
#   adding: content/yolov9/runs/detect/train222/results.png (deflated 5%)
#   adding: content/yolov9/runs/detect/train222/weights/ (stored 0%)
# ...

# %%
# Run inference with the YOLOv9c model on the sample image
results = model('/content/drive/MyDrive/Machine_Learning_CW/Annotated_images/test/images/01_spur_04_resized_jpg.rf.d179b9e936261103661f4f7449b3f7d7.jpg')
# Out:
# image 1/1 /content/drive/MyDrive/Machine_Learning_CW/Annotated_images/test/images/01_spur_04_resized_jpg.rf.d179b9e936261103661f4f7449b3f7d7.jpg: 640x640 (no detections), 49.8ms
# Speed: 1.8ms preprocess, 49.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
results

# %%
# !pip show ultralytics
# Out:
# Name: ultralytics
# Version: 8.1.36
# Summary: Ultralytics YOLOv8 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page:
# Author: Glenn Jocher, Ayush Chaurasia, Jing Qiu
# Author-email:
# License: AGPL-3.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: matplotlib, opencv-python, pandas, pillow, psutil, py-cpuinfo, pyyaml, requests, scipy, seaborn, thop, torch, torchvision, tqdm
# Required-by:

# %%
# !python detect.py --weights /content/drive/MyDrive/best.pt --conf 0.1 --source /content/drive/MyDrive/Machine_Learning_CW/PCB_datasets/PCB_2_D.v1i.yolov9/test/images/01_short_05_resized_jpg.rf.06c8d9b68da2e6a09b9e92ff09ac0f7a.jpg --device 0
# Out:
# detect: weights=['/content/drive/MyDrive/best.pt'], source=/content/drive/MyDrive/Machine_Learning_CW/PCB_datasets/PCB_2_D.v1i.yolov9/test/images/01_short_05_resized_jpg.rf.06c8d9b68da2e6a09b9e92ff09ac0f7a.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# YOLOv9c summary (fused): 384 layers, 25323874 parameters, 0 gradients, 102.3 GFLOPs
# image 1/1 /content/drive/MyDrive/Machine_Learning_CW/PCB_datasets/PCB_2_D.v1i.yolov9/test/images/01_short_05_resized_jpg.rf.06c8d9b68da2e6a09b9e92ff09ac0f7a.jpg: 640x640 3 3s, 49.5ms
# ...

# %%
from IPython.display import Image

Image(filename="/content/yolov9/runs/detect/exp4/01_short_05_resized_jpg.rf.06c8d9b68da2e6a09b9e92ff09ac0f7a.jpg", width=600)

# %%
# !pwd
# Out:
# /content/yolov9

# %%
# !chmod +w detect.py

# %%
# !pip install -q roboflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 27.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 12.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.6 MB/s eta 0:00:00

# %%
# import roboflow
# from roboflow import Roboflow

# rf = Roboflow(api_key="qN2jYKvflo7velAuy6Wb")
# project = rf.workspace("snehanaidu-6jbxy").project("pcb_2")
# version = project.version(1)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# version.deploy(model_type="yolov9", model_path=f"/content/drive/MyDrive")
# Out:
# View the status of your deployment at: https://app.roboflow.com/snehanaidu-6jbxy/pcb_2/1
# Share your model with the world at: https://universe.roboflow.com/snehanaidu-6jbxy/pcb_2/model/1
